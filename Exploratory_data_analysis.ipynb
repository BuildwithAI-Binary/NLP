# %% [markdown]
# # Importing the libraries

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint
from datetime import datetime

#plotting
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

#word count
from collections import Counter

#word clouds
import heapq
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import collections
import matplotlib.cm as cm
from matplotlib import rcParams
from tqdm import tqdm

#sentiment analysis
from textblob import TextBlob

#text preprocessing
from nltk.corpus import stopwords
import nltk
from nltk.stem import WordNetLemmatizer 
nltk.download('stopwords')
nltk.download('wordnet')

#hide warning
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Uploading files on google colab

# %%
import zipfile
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-47a26dab-850a-438e-a49b-516b1fa9f0eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-47a26dab-850a-438e-a49b-516b1fa9f0eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving alone (1).csv to alone (1) (2).csv
# Saving bellletstalk.csv to bellletstalk (2).csv
# Saving chronicillness.csv to chronicillness (2).csv
# Saving depression.csv to depression (2).csv
# Saving fear.csv to fear (2).csv
# Saving mallet-2.0.8.zip to mallet-2.0.8 (1).zip
# Saving meditation.csv to meditation (2).csv
# Saving mentalhealth.csv to mentalhealth (2).csv
# Saving panic.csv to panic (2).csv
# Saving positive.csv to positive (2).csv
# Saving sadness.csv to sadness (2).csv
# Saving smile.csv to smile (1).csv
# Saving stayhome.csv to stayhome (1).csv
# Saving suicide.xlsx to suicide (1).xlsx

# %% [markdown]
# # Importing the dataset

# %%
import io
df_fear = pd.read_csv(io.BytesIO(uploaded['fear.csv']))
df_alone = pd.read_csv(io.BytesIO(uploaded['alone (1).csv']))
df_meditation = pd.read_csv(io.BytesIO(uploaded['meditation.csv']))
df_bellletstalk = pd.read_csv(io.BytesIO(uploaded['bellletstalk.csv']))
df_suicide = pd.read_excel(io.BytesIO(uploaded['suicide.xlsx']))
df_sadness = pd.read_csv(io.BytesIO(uploaded['sadness.csv']))
df_smile= pd.read_csv(io.BytesIO(uploaded['smile.csv']))
df_stayhome= pd.read_csv(io.BytesIO(uploaded['stayhome.csv']))
df_positive= pd.read_csv(io.BytesIO(uploaded['positive.csv']))
df_mentalhealth= pd.read_csv(io.BytesIO(uploaded['mentalhealth.csv']))
df_panic= pd.read_csv(io.BytesIO(uploaded['panic.csv']))
df_chronicillness= pd.read_csv(io.BytesIO(uploaded['chronicillness.csv']))
df_depression= pd.read_csv(io.BytesIO(uploaded['depression.csv']))

# %%
df_fear.head()
# Out:
#             User  ... City
# 0  michaelbarata  ...   NY
# 1    fvnclothing  ...   NY
# 2       jourdaaa  ...   NY
# 3     BebitoToys  ...   NY
# 4    leverage_cr  ...   NY
#
# [5 rows x 7 columns]

# %%
df_alone.head()
# Out:
#               User  ... City
# 0  _TraceDollFace_  ...   NY
# 1  _TraceDollFace_  ...   NY
# 2  _TraceDollFace_  ...   NY
# 3  _TraceDollFace_  ...   NY
# 4  _TraceDollFace_  ...   NY
#
# [5 rows x 7 columns]

# %%
df_meditation.head()
# Out:
#           User  ... City
# 0     jabreu69  ...   NY
# 1  adjust214wb  ...   NY
# 2     jabreu69  ...   NY
# 3  adjust214wb  ...   NY
# 4     jabreu69  ...   NY
#
# [5 rows x 7 columns]

# %%
df_bellletstalk.head()
# Out:
#              User  ... City
# 0  MarleneGinader  ...   NY
# 1       JCCSPORTS  ...   NY
# 2    _MonicaTalks  ...   NY
# 3   PeteSalkowski  ...   NY
# 4  SarahHeartsNYC  ...   NY
#
# [5 rows x 7 columns]

# %%
df_suicide.head()
# Out:
#               User  ... City
# 0  MamaAlboranista  ...   NY
# 1    BelvyBenjamin  ...   NY
# 2    BelvyBenjamin  ...   NY
# 3    BelvyBenjamin  ...   NY
# 4    BelvyBenjamin  ...   NY
#
# [5 rows x 7 columns]

# %%
df_sadness.head()
# Out:
#               User  ... City
# 0           sackec  ...   NY
# 1      JohnnyQ2497  ...   NY
# 2     PrairiesDawn  ...   NY
# 3     leroe24fotos  ...   NY
# 4  coachantonionyc  ...   NY
#
# [5 rows x 7 columns]

# %%
df_smile.head()
# Out:
#               User  ... City
# 0      queenesther  ...   NY
# 1  alshimaahussein  ...   NY
# 2      Thomas__Art  ...   NY
# 3  GothamDogWalker  ...   NY
# 4       em_bem_boo  ...   NY
#
# [5 rows x 7 columns]

# %%
df_stayhome.head()
# Out:
#               User  ... City
# 0  elizabeth_banta  ...   NY
# 1       RaeDiamond  ...   NY
# 2       RaeDiamond  ...   NY
# 3       inwoodgovt  ...   NY
# 4         tbrucato  ...   NY
#
# [5 rows x 7 columns]

# %%
df_positive.head()
# Out:
#               User  ... City
# 0       nanafrombk  ...   NY
# 1       MONTIKILLA  ...   NY
# 2           00PN00  ...   NY
# 3     BronxREAgent  ...   NY
# 4  PelhamParkwayBX  ...   NY
#
# [5 rows x 7 columns]

# %%
df_mentalhealth.head()
# Out:
#             User  ... City
# 0     KleenWraps  ...   NY
# 1        mmaxtra  ...   NY
# 2      ace292325  ...   NY
# 3         sptfit  ...   NY
# 4  p2polefitness  ...   NY
#
# [5 rows x 7 columns]

# %%
df_panic.head()
# Out:
#           User  ... City
# 0    Moosekj25  ...   NY
# 1  fishonkikki  ...   NY
# 2      Nikosak  ...   NY
# 3      Nikosak  ...   NY
# 4  LaPerraShow  ...   NY
#
# [5 rows x 7 columns]

# %%
df_chronicillness.head()
# Out:
#            User  ... City
# 0        bccdny  ...   NY
# 1    Himani0118  ...   NY
# 2     GoldenMoe  ...   NY
# 3  eiramelocin_  ...   NY
# 4    Shanna815x  ...   NY
#
# [5 rows x 7 columns]

# %%
df_depression.head()
# Out:
#               User  ... City
# 0  MamaAlboranista  ...   NY
# 1     nishamarnath  ...   NY
# 2  VerkaikCaroline  ...   NY
# 3    ShirleyRilett  ...   NY
# 4     nytchangster  ...   NY
#
# [5 rows x 7 columns]

# %% [markdown]
# ## shape of our input

# %%
print(df_fear.shape)
print(df_alone.shape)
print(df_sadness.shape)
print(df_suicide.shape)
print(df_panic.shape)
print(df_meditation.shape)
print(df_positive.shape)
print(df_stayhome.shape)
print(df_mentalhealth.shape)
print(df_sadness.shape)
print(df_depression.shape)
print(df_chronicillness.shape)
print(df_bellletstalk.shape)
# Out:
# (630, 7)
# (304, 7)
# (113, 7)
# (520, 7)
# (219, 7)
# (3051, 7)
# (1049, 7)
# (21287, 7)
# (14750, 7)
# (113, 7)
# (1281, 7)
# (219, 7)
# (818, 7)

# %% [markdown]
# # Merging all the dataset

# %%
df= pd.concat([df_fear, df_alone,df_sadness,df_suicide,df_panic,df_meditation,df_bellletstalk,df_positive,df_stayhome,df_mentalhealth,df_sadness,df_depression,df_chronicillness,])

df['date'] = pd.to_datetime(df['Date']).dt.date
df['time'] = pd.to_datetime(df['Date']).dt.time
df['month_year'] = pd.to_datetime(df['Date']).dt.strftime('%Y-%m')

# %%
df=df.drop(['Date'],axis=1)

# %%
# drop duplicate rows
df.drop_duplicates(inplace =True)
df.drop_duplicates(subset = ['Text'],inplace =True)

# %%
df.head()
# Out:
#             User  ... month_year
# 0  michaelbarata  ...    2020-07
# 1    fvnclothing  ...    2020-07
# 2       jourdaaa  ...    2020-07
# 3     BebitoToys  ...    2020-07
# 4    leverage_cr  ...    2020-06
#
# [5 rows x 9 columns]

# %% [markdown]
# # EDA(Exploratory data analysis)

# %%
print('shape:', df.shape)
print('number of tweets:', df['Text'].nunique())
print('number of users:', df['User'].nunique())

print("range:", df['date'].min(),",", df['date'].max())
print("dates:",df['date'].nunique())
# Out:
# shape: (28050, 9)
# number of tweets: 28050
# number of users: 10620
# range: 2019-10-05 , 2020-07-11
# dates: 281

# %%
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns
    
missing_values_table(df)
# Out:
# Your selected dataframe has 9 columns.
# There are 1 columns that have missing values.
#           Missing Values  % of Total Values
# HashTags              28                0.1

# %%
# plot number of tweets everyday
fig = plt.figure(figsize = (10,10))
chart = sns.countplot(df['month_year'], order = sorted(df['month_year'].unique()))
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart.set_title('Number of Tweets per month')
# Out:
# Text(0.5, 1.0, 'Number of Tweets per month')

# %%
fig_dims = (20,15)
fig, ax = plt.subplots(figsize=fig_dims)
chart=sns.countplot(df["City"],palette='Set1',ax=ax)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
chart.set_title('Number of Tweets per city')
# Out:
# Text(0.5, 1.0, 'Number of Tweets per city')

# %%
df.head()
# Out:
#             User  ... month_year
# 0  michaelbarata  ...    2020-07
# 1    fvnclothing  ...    2020-07
# 2       jourdaaa  ...    2020-07
# 3     BebitoToys  ...    2020-07
# 4    leverage_cr  ...    2020-06
#
# [5 rows x 9 columns]

# %%
# plot number of tweets everyday in each city 
pivot = pd.pivot_table(df, index=['City'],
                         columns=['month_year'],
                         values=['Text'], 
                         aggfunc = lambda x: len(x), 
                         fill_value=0)
print(pivot)
print(sorted(df['month_year'].unique()))

fig= plt.figure(figsize = (20,15))
plt.stackplot(sorted(df['month_year'].unique()), pivot.values, labels = pivot.index)
ax = plt.gca()
ax.set_xticks(sorted(df['month_year']))
plt.xticks(rotation=45)
plt.legend(loc='upper left')

plt.title('Number of Tweets in Different Cities Groups across months')
# Out:
#                Text                          ...
# month_year  2019-10 2019-11 2019-12 2020-01  ... 2020-04 2020-05 2020-06 2020-07
# City                                         ...
# BOSTON           74      61      57      84  ...     665     242      82      29
# CHARLOTTE         5       6       1      14  ...      16       3       2       0
# CHI             103      88      72     137  ...     937     326     104      56
# DETROIT          49      47      94     197  ...     255      84      73      23
# GEU              28      27      19      22  ...      19      20      16      22
# HOUSTON          85      90     141     131  ...     168     258     142      47
# LA              404     415     357     566  ...     523     485     352     161
# MIA             121     120     114     148  ...     112     153     137      47
# NEW ORLEANS       5       1       5       1  ...       5       3       6       1
# NEWARK          417     373     359     373  ...     233     318     319     111
# NOLA             22      19      19      51  ...      31      34      24      12
# NY              192     172     206     274  ...    4188    1538     464     182
# O-TOWN           11      10      10      24  ...       7      25      21       8
# PHIL            117     127     115     151  ...     110     104     155      64
# PHOENIX           6       4       9      14  ...      11      11      34       5
# SEATTLE          11       9       4       3  ...       8       5      18       5
# SJ               39      37      34      69  ...      29      44      38      27
# SPB              15      30      28      37  ...      34      28       6       2
# WA               10      13      12      17  ...      22       8      25      10
#
# [19 rows x 10 columns]
# ['2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06', '2020-07']
# Text(0.5, 1.0, 'Number of Tweets in Different Cities Groups across months')

# %%
# extract data that doesn't contain NAs only
df = df[df['HashTags'].notna()]

# %% [markdown]
# # TEXT PREPROCESSING

# %%
# get rid of all kinds of strange symbols from text
def preprocess(Text):
    Text = Text.str.replace("(<br/>)", "")
    Text = Text.str.replace('(<a).*(>).*(</a>)', '')
    Text = Text.str.replace('(&amp)', '')
    Text = Text.str.replace('(&gt)', '')
    Text = Text.str.replace('(&lt)', '')
    Text = Text.str.replace('(\xa0…)', ' ')  
    Text = Text.str.replace('(\n)', ' ')
    Text = Text.str.replace('+', '')
    return Text

# remove urls from text
def remove_urls(row):
    url_pattern = re.compile(r"https?://\S+|www\.\S+")
    row =  url_pattern.sub(r'', row)
    return row

# remove @accounts (@[A-Za-z0–9]+)|, emojis，#hashtags, com frin text
def removes(row):
    url_pattern = re.compile(r"(\w+:\/\/\S+)|(#(\w+))|(.twitter.com/[A-Za-z0–9]+)")
    row =  url_pattern.sub(r'', row)
    return row

# %%
# apply all the preprocess functions
df['text_nlp'] = preprocess(df.Text)
df['text_nlp'] = df['text_nlp'].apply(remove_urls)
df['text_nlp'] = df['text_nlp'].apply(removes)

# %%
# text before preprocessing
df.Text[5]
# Out:
# 5    62 feels good. #reginaedelmanphoto #yoga #hand...
# 5    Damn they told Dave he gotta go home. He had f...
# 5    Crossing the #queensborobridge #sundayfunday w...
# 5    Hope I don’t end up “#missing” or on a tree ha...
# 5    What a couple of drama #queens only you leftis...
# 5    Believe what your heart tells you, not what ot...
# 5    #BellLetsTalk always here for everyone in my l...
# 5    Dear #God, I thank you for being born to #Rosa...
# 5     GOING LIVE! 4PM-6PM TUNE IN TO @bedvynebrew f...
# 5    It was hard to share my story but I realized t...
# 5    The deaths of #poor #BlackLivesMatter #Latinos...
# Name: Text, dtype: object

# %%
# text after preprocessing
df.text_nlp[5]
# Out:
# 5    62 feels good.                  @New York, New...
# 5    Damn they told Dave he gotta go home. He had f...
# 5    Crossing the   w the  after    3 hr  so much  ...
# 5    Hope I don’t end up “” or on a tree hanging by...
# 5    What a couple of drama  only you leftists sens...
# 5    Believe what your heart tells you, not what ot...
# 5     always here for everyone in my life. Nobodys ...
# 5    Dear , I thank you for being born to  and , on...
# 5     GOING LIVE! 4PM-6PM TUNE IN TO @bedvynebrew f...
# 5    It was hard to share my story but I realized t...
# 5    The deaths of     could had been avoided in  b...
# Name: text_nlp, dtype: object

# %%
# Get the lenghth of text and word count
df['text_len'] = df.text_nlp.astype(str).apply(len)
df['word_count'] = df.text_nlp.apply(lambda x: len(str(x).split()))

# %%
# Handling Abbreviation
def decontracted(phrase):
    phrase = re.sub(r"that\'s", "that is", phrase)   
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

# decontracte words
df.text_nlp = df.text_nlp.apply(lambda x: decontracted(x).lower())

# %%
# remove stop words
stop_words = stopwords.words('english')
not_stopwords = {}
common_words =['com','twitter','please',
               'the','would','could','can','may','must', 
              # 'us','i','you','this','we','me','that','it',
               'de','s','pic','t','m','en','la','que','don','re','e','el','ca']
stop_words.extend(word for word in common_words if word not in stop_words)
final_stop_words = set([word for word in stop_words if word not in not_stopwords])
df.text_nlp = df.text_nlp.apply(lambda x: ' '.join([word for word in x.split() if word not in final_stop_words]))

# %%
# remove whitespace and punctuations
rm_punc = re.compile(r"(\W)")
rm_space = re.compile(r"(\s+)")
df.text_nlp = df.text_nlp.apply(lambda x: rm_punc.sub(' ', x))
df.text_nlp = df.text_nlp.apply(lambda x: rm_space.sub(' ', x))

# %%
df.text_nlp[5]
# Out:
# 5                      62 feels good new york new york
# 5             damn told dave gotta go home food eating
# 5    crossing w 3 hr much much time bridge without ...
# 5             hope don t end tree hanging posted this
# 5    couple drama leftists sensed panic one else di...
# 5             believe heart tells you others tell you
# 5    always everyone life nobodys anything alone ok...
# 5                                     dear thank born
# 5    going live 4pm 6pm tune bedvynebrew music djda...
# 5    hard share story realized help somebody bigger...
# 5    deaths avoided negligence take timely measures...
# Name: text_nlp, dtype: object

# %% [markdown]
# # **Sentiment Analysis**

# %%
# get the polarity of each text
df['polarity'] = df.text_nlp.map(lambda text: TextBlob(text).sentiment.polarity)

# classify sentiment into positive and negative ones
df['sentiment'] = ''
df['sentiment'][df['polarity'] > 0] = 'positive'
df['sentiment'][df['polarity'] == 0] = 'neutral'
df['sentiment'][df['polarity'] < 0] = 'negative'
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = plt.figure(figsize=(12,5))
sns.distplot(df['polarity'],kde = False)
plt.ylim(0, 1000)
plt.title("distribution plot")
# Out:
# Text(0.5, 1.0, 'distribution plot')

# %%
df[df['polarity']<-0.8]['Text']
# Out:
# 19       There are 269,000 tons of plastic float in the...
# 115      Being alone isn’t the worst case scenario but ...
# 111      @LoriGrande3 #sadness that the world's biggest...
# 117      #Suicide is a devastating reality among health...
# 23       Make it so I don’t have to go to work, but the...
# 1108     U Ever Notice #DonaldTrump Would Rather Point ...
# 813      #BellLetsTalk @catmsilverman has seen me on so...
# 359       #Played all #day #time to #sleep with my #fav...
# 289                          Disgusted. #stayhome #COVID19
# 906      Those moves are looking insane!!! Mr. Galo’s h...
# 1411     Therapy walk after another horrible night shif...
# 2623     I’m honestly disgusted by the actions of these...
# 3864     Just got a call from the doctor I work with......
# 4488     Watch out! I’m vicious with the sanitizing spr...
# 5357     If we lose 100,000 people that’s more than Kor...
# 6081     This is terrifying!!! #NewYorkTough #StayHome ...
# 6392     Thank you @CatSteadman for Something in the Wa...
# 6556     As if things can’t be more sickening. #COVID19...
# 7098      seriously. There some real evil people out th...
# 7257     The Invisible Man what a movie but tho terrify...
# 7940     My mask is here! Went for a funky color patter...
# 8264     "OHH,BELLA~DONNNAHH!!! NEVAHHH,KNEWW:THEPAiNN!...
# 8623     "EVERYBODY:PLAYS*THE*FOOL!! THERES:NO•EXCEPTiO...
# 8695     Patient with #COVID19 in real bad condition. P...
# 9469     Because retail sales took a sh*t the worst in ...
# 10544    Shocking. I am just so shocked. Idiots! #COVID...
# 10875    Thank you. I know you're trying. I know there ...
# 10918    Days and hours are going like Boring test matc...
# 11002    PSA: Please go to grocery store solo! The numb...
# 11727    Legend-hell if 8 out of 10 hated you. Would yo...
# 13483    Yesterday’s leg and abs session was brutal. Pu...
# 18760    The worst conditions make a champion #thepassi...
# 19493    Just wanted to give another shout out to @LAFi...
# 3814     Kicked me off the field today . Guess what... ...
# 3874     Chest day on Saturday was brutal. #bigguylittl...
# 564      Today has been terrible #HarryPotter #PlayStat...
# 155      Ya know what? Being sick all the time is the f...
# Name: Text, dtype: object

# %%
# Sentiment 
df.groupby('sentiment').Text.count()
# Out:
# sentiment
# negative     3259
# neutral     10764
# positive    13999
# Name: Text, dtype: int64

# %%
# draw a pie chart to show the ratio of 'Negative', 'Neutral' and 'Positive' tweets
fig = plt.figure(figsize=(6,6))
labels = 'Negative', 'Neutral', 'Positive'
sizes = df.groupby('sentiment').Text.count().values
colors = ['gold', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0) 

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.2f%%', shadow=True, startangle=140)
plt.title('The Proportion of Three Sentiments')
plt.show()

# %%
# plot sentiment fluctuation with date
fig, ax1 = plt.subplots(figsize=(10,4))
df.groupby(['date']).mean()['polarity'].plot(kind = 'line')
plt.title('Average sentiment of Tweets across Dates')
# Out:
# Text(0.5, 1.0, 'Average sentiment of Tweets across Dates')

# %% [markdown]
# # **Word Clouds**

# %%
# Create word frequency count
num_words = 300
word2count = {}
for i in tqdm(range(len(df['text_nlp']))): 
    for word in df['text_nlp'].iloc[i].split():
        if word not in word2count.keys(): 
            word2count[word] = 1
        else: 
            word2count[word] += 1
            
freq_words = heapq.nlargest(num_words, word2count, key=word2count.get)
# Out:
# 100%|██████████| 28022/28022 [00:00<00:00, 56192.15it/s]

# %%
from PIL import Image
import requests
from io import BytesIO

# %%
from wordcloud import WordCloud, ImageColorGenerator
from os import path, getcwd
from PIL import Image
d = getcwd()
response = requests.get("https://swissmacuser.ch/wp-content/uploads/2015/09/Twitter_logo_blue.png")
mask = np.array(Image.open(BytesIO(response.content)).convert("RGB"))
response=requests.get("https://previews.123rf.com/images/taiga/taiga1601/taiga160100031/51501178-blue-matrix-abstract-binary-code-digital-background-big-size.jpg")
color = np.array(Image.open(BytesIO(response.content)).convert("RGB"))

def func(arr):   
    if(arr[2]==0):
        return np.array([255,255,255],dtype="uint8")
    else:
        return arr

mask=np.apply_along_axis(func, 2, mask)
#color=np.apply_along_axis(func, 2, color)

# %%
add_stopwords = ['day','like','go','one','today','let','get',
 '2', '1','3','4','5','take','make','think','want','way',
'see','still', 'via', 'now','much', 'even','watch','क',
 'all','really','thing', 'every','around','here','made',
 'also','part','total', 'things',  'little','getting',
 'last','essential','long', 'another', 'look', 'next','there',
 'people','time','new','thank','need','good','going','know',
 'week','everyone','live','love','right','home','us','stay','re',
'help', 'work', 'quarantine', 'life', 'keep', 'york', "york'", 'don']

# Add meaningless words into stopwords
for i in range(len(add_stopwords)):
    STOPWORDS.add(add_stopwords[i])

# %%
wordcloud = WordCloud(width=600, height=500, random_state=1, max_words=num_words, 
                          min_font_size=10,  max_font_size=140,
                          background_color='white',stopwords=set(STOPWORDS),mask = mask)
wordcloud.generate(str(set(df['text_nlp'][df['sentiment'] == 'positive'])))
    # declare our figure  
image_colors = ImageColorGenerator(color)
plt.figure(figsize=(10,9))
plt.title("Word Clouds with Positive Polarity", fontsize=20,color='#0000FF')
plt.imshow(wordcloud, interpolation='bilinear')
plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation='None')
plt.axis('off')
plt.show()

# %%
wordcloud.to_file('positive.png')

# %%
response=requests.get("https://images.pexels.com/photos/960137/pexels-photo-960137.jpeg?cs=srgb&dl=red-wooden-surface-960137.jpg&fm=jpg")
red = np.array(Image.open(BytesIO(response.content)).convert("RGB"))
red=np.apply_along_axis(func, 2, red)

# %%
wordcloud = WordCloud(width=600, height=500, random_state=1, max_words=num_words, 
                          min_font_size=10,  max_font_size=140,
                          background_color='white', stopwords=set(STOPWORDS),mask = mask)
wordcloud.generate(str(set(df['text_nlp'][df['sentiment'] == 'negative'])))
    # declare our figure  
image_colors = ImageColorGenerator(red)
plt.figure(figsize=(10,9))
plt.title("Word Clouds with negative Polarity", fontsize=20,color='#DE2929')
plt.imshow(wordcloud, interpolation='bilinear')
plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation='None')
plt.axis('off')
plt.show()

# %%
wordcloud.to_file('negative.png')

# %% [markdown]
# # **Topic Modelling**

# %% [markdown]
# ## preprocessing for Topic Modeling¶

# %%
#Installing the libraries
# !pip install pyLDAvis
# Out:
# Collecting pyLDAvis
#   Downloading https://files.pythonhosted.org/packages/a5/3a/af82e070a8a96e13217c8f362f9a73e82d61ac8fff3a2561946a97f96266/pyLDAvis-2.1.2.tar.gz (1.6MB)
#      |████████████████████████████████| 1.6MB 2.7MB/s
# Requirement already satisfied: wheel>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (0.34.2)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (1.18.5)
# Requirement already satisfied: scipy>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: pandas>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (1.0.5)
# Requirement already satisfied: joblib>=0.8.4 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: jinja2>=2.7.2 in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (2.11.2)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (2.7.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (3.6.4)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyLDAvis) (0.16.0)
# Collecting funcy
#   Downloading https://files.pythonhosted.org/packages/ce/4b/6ffa76544e46614123de31574ad95758c421aae391a1764921b8a81e1eae/funcy-1.14.tar.gz (548kB)
#      |████████████████████████████████| 552kB 39kB/s
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.17.0->pyLDAvis) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.17.0->pyLDAvis) (2018.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2>=2.7.2->pyLDAvis) (1.1.1)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (8.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (49.1.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (1.9.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (1.15.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (1.4.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (0.7.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest->pyLDAvis) (19.3.0)
# Building wheels for collected packages: pyLDAvis, funcy
#   Building wheel for pyLDAvis (setup.py) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-2.1.2-py2.py3-none-any.whl size=97711 sha256=ce75d67c5be88a90c46d92401d0787731ce5beb1f7d38ff6c70ef67c81215e28
#   Stored in directory: /root/.cache/pip/wheels/98/71/24/513a99e58bb6b8465bae4d2d5e9dba8f0bef8179e3051ac414
#   Building wheel for funcy (setup.py) ... done
#   Created wheel for funcy: filename=funcy-1.14-py2.py3-none-any.whl size=32042 sha256=4e6b3508d693a8870f089a47ea99660c5aa36aaea04e3ada10ee720118c3b722
#   Stored in directory: /root/.cache/pip/wheels/20/5a/d8/1d875df03deae6f178dfdf70238cca33f948ef8a6f5209f2eb
# Successfully built pyLDAvis funcy
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-1.14 pyLDAvis-2.1.2

# %%
# !pip install gensim --upgrade
# Out:
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/2b/e0/fa6326251692056dc880a64eb22117e03269906ba55a6864864d24ec8b4e/gensim-3.8.3-cp36-cp36m-manylinux1_x86_64.whl (24.2MB)
#      |████████████████████████████████| 24.2MB 1.3MB/s
# Requirement already satisfied, skipping upgrade: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (2.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.18.5)
# Requirement already satisfied, skipping upgrade: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim) (1.14.24)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim) (2.23.0)
# Requirement already satisfied, skipping upgrade: boto in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim) (0.10.0)
# Requirement already satisfied, skipping upgrade: botocore<1.18.0,>=1.17.24 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim) (1.17.24)
# Requirement already satisfied, skipping upgrade: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim) (0.3.3)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (2020.6.20)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.24->boto3->smart-open>=1.8.1->gensim) (0.15.2)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.24->boto3->smart-open>=1.8.1->gensim) (2.8.1)
# Installing collected packages: gensim
#   Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-3.8.3

# %%
'''import os       #importing os to set environment variable
def install_java():
  # !apt-get install -y openjdk-8-jdk-headless -qq > /dev/null      #install openjdk
  os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"     #set environment variable
  # !java -version       #check java version
install_java()'''
# Out:
# 'import os       #importing os to set environment variable\ndef install_java():\n  !apt-get install -y openjdk-8-jdk-headless -qq > /dev/null      #install openjdk\n  os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"     #set environment variable\n  !java -version       #check java version\ninstall_java()'

# %%
# !wget http://mallet.cs.umass.edu/dist/mallet-2.0.8.zip
# !unzip mallet-2.0.8.zip
# Out:
# --2020-07-27 06:58:24--  http://mallet.cs.umass.edu/dist/mallet-2.0.8.zip
# Resolving mallet.cs.umass.edu (mallet.cs.umass.edu)... 128.119.246.70
# Connecting to mallet.cs.umass.edu (mallet.cs.umass.edu)|128.119.246.70|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16184794 (15M) [application/zip]
# Saving to: ‘mallet-2.0.8.zip.1’
#
# mallet-2.0.8.zip.1  100%[===================>]  15.43M  5.68MB/s    in 2.7s
#
# 2020-07-27 06:58:27 (5.68 MB/s) - ‘mallet-2.0.8.zip.1’ saved [16184794/16184794]
#
# Archive:  mallet-2.0.8.zip
#    creating: mallet-2.0.8/
#    creating: mallet-2.0.8/stoplists/
#   inflating: mallet-2.0.8/stoplists/en.txt
#    creating: __MACOSX/
#    creating: __MACOSX/mallet-2.0.8/
#    creating: __MACOSX/mallet-2.0.8/stoplists/
#   inflating: __MACOSX/mallet-2.0.8/stoplists/._en.txt
#   inflating: mallet-2.0.8/stoplists/fr.txt
#   inflating: __MACOSX/mallet-2.0.8/stoplists/._fr.txt
#   inflating: mallet-2.0.8/stoplists/jp.txt
#   inflating: __MACOSX/mallet-2.0.8/stoplists/._jp.txt
#   inflating: mallet-2.0.8/stoplists/README
#   inflating: __MACOSX/mallet-2.0.8/stoplists/._README
#   inflating: mallet-2.0.8/stoplists/fi.txt
#   inflating: __MACOSX/mallet-2.0.8/stoplists/._fi.txt
#   inflating: mallet-2.0.8/stoplists/de.txt
#   inflating: __MACOSX/mallet-2.0.8/stoplists/._de.txt
#   inflating: __MACOSX/mallet-2.0.8/._stoplists
#   inflating: mallet-2.0.8/LICENSE
#   inflating: __MACOSX/mallet-2.0.8/._LICENSE
#    creating: mallet-2.0.8/test/
#   inflating: __MACOSX/mallet-2.0.8/._test
#    creating: mallet-2.0.8/bin/
#   inflating: mallet-2.0.8/bin/svmlight2vectors
#    creating: __MACOSX/mallet-2.0.8/bin/
#   inflating: __MACOSX/mallet-2.0.8/bin/._svmlight2vectors
#   inflating: mallet-2.0.8/bin/csv2vectors
#   inflating: __MACOSX/mallet-2.0.8/bin/._csv2vectors
#   inflating: mallet-2.0.8/bin/vectors2vectors
#   inflating: __MACOSX/mallet-2.0.8/bin/._vectors2vectors
#   inflating: mallet-2.0.8/bin/csv2classify
#   inflating: __MACOSX/mallet-2.0.8/bin/._csv2classify
#   inflating: mallet-2.0.8/bin/mallet.bat
#   inflating: __MACOSX/mallet-2.0.8/bin/._mallet.bat
#   inflating: mallet-2.0.8/bin/text2classify
#   inflating: __MACOSX/mallet-2.0.8/bin/._text2classify
#   inflating: mallet-2.0.8/bin/vectors2topics
#   inflating: __MACOSX/mallet-2.0.8/bin/._vectors2topics
#   inflating: mallet-2.0.8/bin/vectors2info
#   inflating: __MACOSX/mallet-2.0.8/bin/._vectors2info
#   inflating: mallet-2.0.8/bin/mallet
#   inflating: __MACOSX/mallet-2.0.8/bin/._mallet
#   inflating: mallet-2.0.8/bin/prepend-license.sh
#   inflating: __MACOSX/mallet-2.0.8/bin/._prepend-license.sh
#   inflating: mallet-2.0.8/bin/mallethon
#   inflating: __MACOSX/mallet-2.0.8/bin/._mallethon
#   inflating: mallet-2.0.8/bin/vectors2classify
#   inflating: __MACOSX/mallet-2.0.8/bin/._vectors2classify
#   inflating: mallet-2.0.8/bin/classifier2info
#   inflating: __MACOSX/mallet-2.0.8/bin/._classifier2info
#   inflating: mallet-2.0.8/bin/text2vectors
#   inflating: __MACOSX/mallet-2.0.8/bin/._text2vectors
#   inflating: __MACOSX/mallet-2.0.8/._bin
#    creating: mallet-2.0.8/dist/
#   inflating: mallet-2.0.8/dist/mallet-deps.jar
#    creating: __MACOSX/mallet-2.0.8/dist/
#   inflating: __MACOSX/mallet-2.0.8/dist/._mallet-deps.jar
#   inflating: mallet-2.0.8/dist/mallet.jar
#   inflating: __MACOSX/mallet-2.0.8/dist/._mallet.jar
#   inflating: __MACOSX/mallet-2.0.8/._dist
#   inflating: mallet-2.0.8/build.xml
#   inflating: __MACOSX/mallet-2.0.8/._build.xml
#   inflating: mallet-2.0.8/Makefile
#   inflating: __MACOSX/mallet-2.0.8/._Makefile
#   inflating: mallet-2.0.8/pom.xml
#   inflating: __MACOSX/mallet-2.0.8/._pom.xml
#   inflating: mallet-2.0.8/README.md
#   inflating: __MACOSX/mallet-2.0.8/._README.md
#    creating: mallet-2.0.8/class/
#    creating: mallet-2.0.8/class/cc/
#    creating: mallet-2.0.8/class/cc/mallet/
#    creating: mallet-2.0.8/class/cc/mallet/cluster/
#    creating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/MedoidEvaluator$Minimum.class
#    creating: __MACOSX/mallet-2.0.8/class/
#    creating: __MACOSX/mallet-2.0.8/class/cc/
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._MedoidEvaluator$Minimum.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/MedoidEvaluator$Average.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._MedoidEvaluator$Average.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/ClassifyingNeighborEvaluator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._ClassifyingNeighborEvaluator.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/MedoidEvaluator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._MedoidEvaluator.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/Neighbor.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._Neighbor.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/PairwiseEvaluator$Average.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._PairwiseEvaluator$Average.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/RankingNeighborEvaluator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._RankingNeighborEvaluator.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/RandomEvaluator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._RandomEvaluator.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/PairwiseEvaluator$Minimum.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._PairwiseEvaluator$Minimum.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/NeighborEvaluator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._NeighborEvaluator.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/PairwiseEvaluator$Maximum.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._PairwiseEvaluator$Maximum.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/AgglomerativeNeighbor.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._AgglomerativeNeighbor.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/PairwiseEvaluator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._PairwiseEvaluator.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/MedoidEvaluator$Maximum.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._MedoidEvaluator$Maximum.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/PairwiseEvaluator$CombiningStrategy.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._PairwiseEvaluator$CombiningStrategy.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/MedoidEvaluator$CombiningStrategy.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/neighbor_evaluator/._MedoidEvaluator$CombiningStrategy.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._neighbor_evaluator
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/KMeans.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._KMeans.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/Clustering.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._Clustering.class
#    creating: mallet-2.0.8/class/cc/mallet/cluster/util/
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/util/PairwiseMatrix.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/util/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/util/._PairwiseMatrix.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/util/ClusterUtils.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/util/._ClusterUtils.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._util
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/Clusterer.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._Clusterer.class
#    creating: mallet-2.0.8/class/cc/mallet/cluster/tui/
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/tui/Clusterings2Clusterings.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/tui/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/tui/._Clusterings2Clusterings.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/tui/Text2Clusterings.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/tui/._Text2Clusterings.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/tui/Clusterings2Clusterer$ClusteringPipe.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/tui/._Clusterings2Clusterer$ClusteringPipe.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/tui/Clusterings2Clusterer.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/tui/._Clusterings2Clusterer.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/tui/Clusterings2Info.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/tui/._Clusterings2Info.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._tui
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/KBestClusterer.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._KBestClusterer.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/Clusterings.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._Clusterings.class
#    creating: mallet-2.0.8/class/cc/mallet/cluster/iterator/
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/iterator/AllPairsIterator.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/iterator/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/iterator/._AllPairsIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/iterator/NodeClusterSampleIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/iterator/._NodeClusterSampleIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/iterator/PairSampleIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/iterator/._PairSampleIterator.class
#    creating: mallet-2.0.8/class/cc/mallet/cluster/iterator/tests/
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/iterator/tests/TestIterators.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/iterator/tests/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/iterator/tests/._TestIterators.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/iterator/._tests
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/iterator/ClusterSampleIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/iterator/._ClusterSampleIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/iterator/NeighborIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/iterator/._NeighborIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._iterator
#    creating: mallet-2.0.8/class/cc/mallet/cluster/evaluate/
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/evaluate/PairF1Evaluator.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/evaluate/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/evaluate/._PairF1Evaluator.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/evaluate/MUCEvaluator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/evaluate/._MUCEvaluator.class
#    creating: mallet-2.0.8/class/cc/mallet/cluster/evaluate/tests/
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/evaluate/tests/TestClusteringEvaluators.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/evaluate/tests/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/evaluate/tests/._TestClusteringEvaluators.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/evaluate/._tests
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/evaluate/AccuracyEvaluator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/evaluate/._AccuracyEvaluator.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/evaluate/ClusteringEvaluators.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/evaluate/._ClusteringEvaluators.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/evaluate/ClusteringEvaluator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/evaluate/._ClusteringEvaluator.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/evaluate/BCubedEvaluator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/evaluate/._BCubedEvaluator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._evaluate
#    creating: mallet-2.0.8/class/cc/mallet/cluster/clustering_scorer/
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/clustering_scorer/ClusteringScorer.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/clustering_scorer/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/clustering_scorer/._ClusteringScorer.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/clustering_scorer/PairwiseScorer.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/clustering_scorer/._PairwiseScorer.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._clustering_scorer
#    creating: mallet-2.0.8/class/cc/mallet/cluster/examples/
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/examples/FirstOrderClusterExample$OverlappingFeaturePipe.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/examples/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/examples/._FirstOrderClusterExample$OverlappingFeaturePipe.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/examples/FirstOrderClusterExample.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/examples/._FirstOrderClusterExample.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._examples
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/GreedyAgglomerativeByDensity.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._GreedyAgglomerativeByDensity.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/Record.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._Record.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/HillClimbingClusterer.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._HillClimbingClusterer.class
#   inflating: mallet-2.0.8/class/cc/mallet/cluster/GreedyAgglomerative.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/cluster/._GreedyAgglomerative.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/._cluster
#    creating: mallet-2.0.8/class/cc/mallet/pipe/
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/PrintInput.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._PrintInput.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/StringAddNewLineDelimiter.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._StringAddNewLineDelimiter.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/CharSequenceLowercase.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._CharSequenceLowercase.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/CharSubsequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._CharSubsequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/NGramPreprocessor$ReplacementSet.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._NGramPreprocessor$ReplacementSet.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/BranchingPipe$1.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._BranchingPipe$1.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/SerialPipes$Predicate.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._SerialPipes$Predicate.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/FeatureValueString2FeatureVector.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._FeatureValueString2FeatureVector.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Filename2CharSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Filename2CharSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/TokenSequence2TokenInstances.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._TokenSequence2TokenInstances.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/CharSequenceRemoveHTML$ParserGetter.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._CharSequenceRemoveHTML$ParserGetter.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/FeatureSequenceConvolution.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._FeatureSequenceConvolution.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/FeatureVectorSequence2FeatureVectors.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._FeatureVectorSequence2FeatureVectors.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/SelectiveSGML2TokenSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._SelectiveSGML2TokenSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/CharSequenceRemoveHTML$1.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._CharSequenceRemoveHTML$1.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/BranchingPipe.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._BranchingPipe.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/TokenSequenceMatchDataAndTarget.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._TokenSequenceMatchDataAndTarget.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/TokenSequence2FeatureSequenceWithBigrams.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._TokenSequence2FeatureSequenceWithBigrams.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/AugmentableFeatureVectorLogScale.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._AugmentableFeatureVectorLogScale.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/CharSequence2TokenSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._CharSequence2TokenSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/FilterEmptyFeatureVectors$FilteringPipeInstanceIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._FilterEmptyFeatureVectors$FilteringPipeInstanceIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/MakeAmpersandXMLFriendly.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._MakeAmpersandXMLFriendly.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/CharSequence2CharNGrams.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._CharSequence2CharNGrams.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Target2Double.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Target2Double.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/FeatureVectorConjunctions.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._FeatureVectorConjunctions.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/CharSequenceRemoveUUEncodedBlocks.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._CharSequenceRemoveUUEncodedBlocks.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/ValueString2FeatureVector.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._ValueString2FeatureVector.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/BranchingPipe$BranchingInstanceIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._BranchingPipe$BranchingInstanceIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/CharSequenceArray2TokenSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._CharSequenceArray2TokenSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/BranchingPipe$GateKeepingInstanceIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._BranchingPipe$GateKeepingInstanceIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/TokenSequenceRemoveNonAlpha.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._TokenSequenceRemoveNonAlpha.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/SerialPipes.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._SerialPipes.class
#    creating: mallet-2.0.8/class/cc/mallet/pipe/tests/
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tests/TestSpacePipe.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tests/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tests/._TestSpacePipe.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tests/TestPipeUtils$StupidPipe.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tests/._TestPipeUtils$StupidPipe.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tests/TestInstancePipe$Array2ArrayIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tests/._TestInstancePipe$Array2ArrayIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tests/TestSGML2TokenSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tests/._TestSGML2TokenSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tests/TestRainbowStyle.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tests/._TestRainbowStyle.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tests/TestSGML2TokenSequence$Array2ArrayIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tests/._TestSGML2TokenSequence$Array2ArrayIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tests/TestInstancePipe.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tests/._TestInstancePipe.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tests/TestPipeUtils.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tests/._TestPipeUtils.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tests/TestIterators.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tests/._TestIterators.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tests/TestPipeUtils$1.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tests/._TestPipeUtils$1.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._tests
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/FilterEmptyFeatureVectors.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._FilterEmptyFeatureVectors.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/PrintInputAndTarget.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._PrintInputAndTarget.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Array2FeatureVector.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Array2FeatureVector.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/FeatureDocFreqPipe.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._FeatureDocFreqPipe.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/FeatureCountPipe.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._FeatureCountPipe.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/CharSequenceReplace.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._CharSequenceReplace.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Target2LabelSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Target2LabelSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Input2CharSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Input2CharSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Classification2ConfidencePredictingFeatureVector.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Classification2ConfidencePredictingFeatureVector.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/TokenSequenceRemoveStopPatterns.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._TokenSequenceRemoveStopPatterns.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Pipe.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Pipe.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/TokenSequence2FeatureSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._TokenSequence2FeatureSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/AddClassifierTokenPredictions.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._AddClassifierTokenPredictions.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/SimpleTaggerSentence2TokenSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._SimpleTaggerSentence2TokenSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Csv2Array.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Csv2Array.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/SimpleTaggerSentence2StringTokenization.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._SimpleTaggerSentence2StringTokenization.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/AddClassifierTokenPredictions$TokenClassifiers.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._AddClassifierTokenPredictions$TokenClassifiers.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/SvmLight2FeatureVectorAndLabel.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._SvmLight2FeatureVectorAndLabel.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/TokenSequenceParseFeatureString.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._TokenSequenceParseFeatureString.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/NGramPreprocessor.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._NGramPreprocessor.class
#    creating: mallet-2.0.8/class/cc/mallet/pipe/iterator/
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/ConcatenatedInstanceIterator.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._ConcatenatedInstanceIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/CsvIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._CsvIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/UnlabeledFileIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._UnlabeledFileIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/PipeInputIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._PipeInputIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/PatternMatchIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._PatternMatchIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/ArrayIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._ArrayIterator.class
#    creating: mallet-2.0.8/class/cc/mallet/pipe/iterator/tests/
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/tests/TestPatternMatchIterator.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/tests/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/tests/._TestPatternMatchIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._tests
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/EmptyInstanceIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._EmptyInstanceIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/LineGroupIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._LineGroupIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/SimpleFileLineIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._SimpleFileLineIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/FileListIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._FileListIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/SegmentIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._SegmentIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/FileUriIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._FileUriIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/StringArrayIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._StringArrayIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/DBInstanceIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._DBInstanceIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/RandomTokenSequenceIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._RandomTokenSequenceIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/ArrayDataAndTargetIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._ArrayDataAndTargetIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/SelectiveFileLineIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._SelectiveFileLineIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/ParenGroupIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._ParenGroupIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/RandomFeatureVectorIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._RandomFeatureVectorIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/LineIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._LineIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/PipeExtendedIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._PipeExtendedIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/iterator/FileIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/iterator/._FileIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._iterator
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Target2FeatureSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Target2FeatureSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/SimpleTokenizer.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._SimpleTokenizer.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/PipeUtils.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._PipeUtils.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Pipe$SimplePipeInstanceIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Pipe$SimplePipeInstanceIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/CharSequenceRemoveHTML$TagStripper.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._CharSequenceRemoveHTML$TagStripper.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/TokenSequenceLowercase.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._TokenSequenceLowercase.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Token2FeatureVector.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Token2FeatureVector.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/FixedVocabTokenizer.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._FixedVocabTokenizer.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/InstanceListTrimFeaturesByCount.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._InstanceListTrimFeaturesByCount.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Target2Label.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Target2Label.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Directory2FileIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Directory2FileIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/TokenSequence2TokenInstances$TokenInstanceIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._TokenSequence2TokenInstances$TokenInstanceIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/CharSequenceRemoveHTML.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._CharSequenceRemoveHTML.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/BranchingPipe$PeekingInstanceIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._BranchingPipe$PeekingInstanceIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/TargetStringToFeatures.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._TargetStringToFeatures.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/FeatureVectorSequence2FeatureVectors$FeatureVectorIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._FeatureVectorSequence2FeatureVectors$FeatureVectorIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Noop.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Noop.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/TargetRememberLastLabel.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._TargetRememberLastLabel.class
#    creating: mallet-2.0.8/class/cc/mallet/pipe/tsf/
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/OffsetPropertyConjunctions.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._OffsetPropertyConjunctions.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/TokenTextNGrams.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._TokenTextNGrams.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/FeaturesInWindow.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._FeaturesInWindow.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/TokenTextCharNGrams.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._TokenTextCharNGrams.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/FeaturesOfFirstMention.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._FeaturesOfFirstMention.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/SequencePrintingPipe.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._SequencePrintingPipe.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/TokenFirstPosition.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._TokenFirstPosition.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/CountMatchesAlignedWithOffsets.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._CountMatchesAlignedWithOffsets.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/CountMatchesMatching.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._CountMatchesMatching.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/OffsetFeatureConjunction.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._OffsetFeatureConjunction.class
#    creating: mallet-2.0.8/class/cc/mallet/pipe/tsf/tests/
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/tests/TestOffsetConjunctions.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/tests/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/tests/._TestOffsetConjunctions.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/tests/TestOffsetFeatureConjunctions.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/tests/._TestOffsetFeatureConjunctions.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/tests/TestSequencePrintingPipe.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/tests/._TestSequencePrintingPipe.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._tests
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/TokenText.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._TokenText.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/Target2BIOFormat.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._Target2BIOFormat.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/CountMatches.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._CountMatches.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/WordVectors.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._WordVectors.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/TrieLexiconMembership$TrieLexicon.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._TrieLexiconMembership$TrieLexicon.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/OffsetConjunctions.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._OffsetConjunctions.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/TokenTextCharSuffix.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._TokenTextCharSuffix.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/LexiconMembership.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._LexiconMembership.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/TrieLexiconMembership.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._TrieLexiconMembership.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/TokenTextCharPrefix.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._TokenTextCharPrefix.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/tsf/RegexMatches.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/tsf/._RegexMatches.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._tsf
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/PipeException.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._PipeException.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/SGML2TokenSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._SGML2TokenSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Target2Integer.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Target2Integer.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/TokenSequenceNGrams.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._TokenSequenceNGrams.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/SaveDataInSource.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._SaveDataInSource.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/TokenSequence2FeatureVectorSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._TokenSequence2FeatureVectorSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/FeatureSequence2AugmentableFeatureVector.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._FeatureSequence2AugmentableFeatureVector.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/TokenSequenceRemoveStopwords.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._TokenSequenceRemoveStopwords.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/LineGroupString2TokenSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._LineGroupString2TokenSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/StringList2FeatureSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._StringList2FeatureSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/SourceLocation2TokenSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._SourceLocation2TokenSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/FeatureSequence2FeatureVector.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._FeatureSequence2FeatureVector.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/PrintTokenSequenceFeatures.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._PrintTokenSequenceFeatures.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/Csv2FeatureVector.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._Csv2FeatureVector.class
#   inflating: mallet-2.0.8/class/cc/mallet/pipe/AugmentableFeatureVectorAddConjunctions.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/pipe/._AugmentableFeatureVectorAddConjunctions.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/._pipe
#    creating: mallet-2.0.8/class/cc/mallet/types/
#   inflating: mallet-2.0.8/class/cc/mallet/types/GradientGain.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._GradientGain.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/Dirichlet$MethodOfMomentsEstimator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._Dirichlet$MethodOfMomentsEstimator.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/Dirichlet$Estimator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._Dirichlet$Estimator.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/FeatureVectorSequence$Iterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._FeatureVectorSequence$Iterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/LogNumber.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._LogNumber.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/PartiallyRankedFeatureVector$PerLabelFactory.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._PartiallyRankedFeatureVector$PerLabelFactory.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/Metric.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._Metric.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/Multinomial$Logged.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._Multinomial$Logged.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/CrossValidationIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._CrossValidationIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/FeatureCounts$Factory.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._FeatureCounts$Factory.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/Label.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._Label.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/ManhattenDistance.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._ManhattenDistance.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/FeatureCounter.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._FeatureCounter.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/Dirichlet.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._Dirichlet.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/BiNormalSeparation$Factory.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._BiNormalSeparation$Factory.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/StringKernel.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._StringKernel.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/GainRatio$1.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._GainRatio$1.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/AugmentableFeatureVector.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._AugmentableFeatureVector.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/GradientGain$Factory.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._GradientGain$Factory.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/KLGain.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._KLGain.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/InfoGain$Factory.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._InfoGain$Factory.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/MultiInstanceList.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._MultiInstanceList.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/Labelings.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._Labelings.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/Labeler.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._Labeler.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/MultiInstanceList$MultiIterator.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._MultiInstanceList$MultiIterator.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/RankedFeatureVector.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._RankedFeatureVector.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/LabelSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._LabelSequence.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/CachedMetric.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._CachedMetric.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/FeatureSequenceWithBigrams.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._FeatureSequenceWithBigrams.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/PropertyHolder.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._PropertyHolder.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/ExpGain.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._ExpGain.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/LabelsSequence.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/._LabelsSequence.class
#    creating: mallet-2.0.8/class/cc/mallet/types/tests/
#   inflating: mallet-2.0.8/class/cc/mallet/types/tests/TestMultinomial.class
#    creating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/tests/
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/tests/._TestMultinomial.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/tests/TestRankedFeatureVector.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/tests/._TestRankedFeatureVector.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/tests/TestAugmentableFeatureVector.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/tests/._TestAugmentableFeatureVector.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/tests/TestMatrixn.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/tests/._TestMatrixn.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/tests/TestHashedSparseVector.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/tests/._TestHashedSparseVector.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/tests/TestSerializable$WriteMe.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/tests/._TestSerializable$WriteMe.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/tests/TestSparseMatrixn.class
#   inflating: __MACOSX/mallet-2.0.8/class/cc/mallet/types/tests/._TestSparseMatrixn.class
#   inflating: mallet-2.0.8/class/cc/mallet/types/tests/TestAlphabet.class
# ...
#   inflating: mallet-2.0.8/src/cc/mallet/fst/semi_supervised/CRFOptimizableByEntropyRegularization.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/semi_supervised/._CRFOptimizableByEntropyRegularization.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/semi_supervised/CRFTrainerByGE.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/semi_supervised/._CRFTrainerByGE.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._semi_supervised
#   inflating: mallet-2.0.8/src/cc/mallet/fst/CRFOptimizableByLabelLikelihood.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._CRFOptimizableByLabelLikelihood.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/SumLattice.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._SumLattice.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/Segment.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._Segment.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/CacheStaleIndicator.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._CacheStaleIndicator.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/SegmentationEvaluator.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._SegmentationEvaluator.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/ShallowTransducerTrainer.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._ShallowTransducerTrainer.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/TransducerTrainer.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._TransducerTrainer.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/LabelDistributionEvaluator.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._LabelDistributionEvaluator.java
#    creating: mallet-2.0.8/src/cc/mallet/fst/tests/
#   inflating: mallet-2.0.8/src/cc/mallet/fst/tests/package.html
#    creating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/tests/
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/tests/._package.html
#   inflating: mallet-2.0.8/src/cc/mallet/fst/tests/TestSumNegLogProb2.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/tests/._TestSumNegLogProb2.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/tests/TestCRF.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/tests/._TestCRF.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/tests/TestMEMM.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/tests/._TestMEMM.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/tests/TestFeatureTransducer.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/tests/._TestFeatureTransducer.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._tests
#   inflating: mallet-2.0.8/src/cc/mallet/fst/SimpleTagger.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._SimpleTagger.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/package.html
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._package.html
#   inflating: mallet-2.0.8/src/cc/mallet/fst/MaxLatticeDefault.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._MaxLatticeDefault.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/Transducer.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._Transducer.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/TokenAccuracyEvaluator.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._TokenAccuracyEvaluator.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/SumLatticeScaling.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._SumLatticeScaling.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/MaxLattice.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._MaxLattice.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/HMM.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._HMM.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/SumLatticeDefault.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._SumLatticeDefault.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/NoopTransducerTrainer.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._NoopTransducerTrainer.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/PerClassAccuracyEvaluator.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._PerClassAccuracyEvaluator.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/CRFTrainerByValueGradients.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._CRFTrainerByValueGradients.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/FeatureTransducer.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._FeatureTransducer.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/CRFTrainerByStochasticGradient.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._CRFTrainerByStochasticGradient.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/SumLatticeBeam.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._SumLatticeBeam.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/MEMMTrainer.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._MEMMTrainer.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/SumLatticeConstrained.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._SumLatticeConstrained.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/SumLatticeFactory.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._SumLatticeFactory.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/CRFTrainerByLabelLikelihood.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._CRFTrainerByLabelLikelihood.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/MultiSegmentationEvaluator.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._MultiSegmentationEvaluator.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/ThreadedOptimizable.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._ThreadedOptimizable.java
#   inflating: mallet-2.0.8/src/cc/mallet/fst/TransducerEvaluator.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/fst/._TransducerEvaluator.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/._fst
#    creating: mallet-2.0.8/src/cc/mallet/topics/
#   inflating: mallet-2.0.8/src/cc/mallet/topics/LDAStream.java
#    creating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._LDAStream.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/TopicReports.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._TopicReports.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/MultinomialHMM.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._MultinomialHMM.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/MarginalProbEstimator.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._MarginalProbEstimator.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/HierarchicalLDA.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._HierarchicalLDA.java
#    creating: mallet-2.0.8/src/cc/mallet/topics/tui/
#   inflating: mallet-2.0.8/src/cc/mallet/topics/tui/EvaluateTopics.java
#    creating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/tui/
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/tui/._EvaluateTopics.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/tui/DMRLoader.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/tui/._DMRLoader.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/tui/HierarchicalLDATUI.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/tui/._HierarchicalLDATUI.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/tui/TopicTrainer.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/tui/._TopicTrainer.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/tui/InferTopics.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/tui/._InferTopics.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/tui/Vectors2Topics.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/tui/._Vectors2Topics.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._tui
#   inflating: mallet-2.0.8/src/cc/mallet/topics/PolylingualTopicModel.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._PolylingualTopicModel.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/WordEmbeddingRunnable.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._WordEmbeddingRunnable.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/WordEmbeddings.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._WordEmbeddings.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/SimpleLDA.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._SimpleLDA.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/HierarchicalPAM.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._HierarchicalPAM.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/TopicalNGrams.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._TopicalNGrams.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/AbstractTopicReports.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._AbstractTopicReports.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/LDA.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._LDA.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/JSONTopicReports.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._JSONTopicReports.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/LDAHyper.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._LDAHyper.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/ParallelTopicModel.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._ParallelTopicModel.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/DMRTopicModel.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._DMRTopicModel.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/TopicModelDiagnostics.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._TopicModelDiagnostics.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/NPTopicModel.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._NPTopicModel.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/TopicAssignment.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._TopicAssignment.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/LabeledLDA.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._LabeledLDA.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/WeightedTopicModel.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._WeightedTopicModel.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/RTopicModel.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._RTopicModel.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/WorkerRunnable.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._WorkerRunnable.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/PAM4L.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._PAM4L.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/TopicInferencer.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._TopicInferencer.java
#   inflating: mallet-2.0.8/src/cc/mallet/topics/DMROptimizable.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/topics/._DMROptimizable.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/._topics
#    creating: mallet-2.0.8/src/cc/mallet/share/
#    creating: mallet-2.0.8/src/cc/mallet/share/upenn/
#    creating: mallet-2.0.8/src/cc/mallet/share/upenn/ner/
#   inflating: mallet-2.0.8/src/cc/mallet/share/upenn/ner/LongRegexMatches.java
#    creating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/
#    creating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/upenn/
#    creating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/upenn/ner/
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/upenn/ner/._LongRegexMatches.java
#   inflating: mallet-2.0.8/src/cc/mallet/share/upenn/ner/ListMember.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/upenn/ner/._ListMember.java
#   inflating: mallet-2.0.8/src/cc/mallet/share/upenn/ner/FeatureWindow.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/upenn/ner/._FeatureWindow.java
#   inflating: mallet-2.0.8/src/cc/mallet/share/upenn/ner/LengthBins.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/upenn/ner/._LengthBins.java
#   inflating: mallet-2.0.8/src/cc/mallet/share/upenn/ner/NEPipes.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/upenn/ner/._NEPipes.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/upenn/._ner
#   inflating: mallet-2.0.8/src/cc/mallet/share/upenn/package.html
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/upenn/._package.html
#   inflating: mallet-2.0.8/src/cc/mallet/share/upenn/MaxEntShell.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/upenn/._MaxEntShell.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/._upenn
#    creating: mallet-2.0.8/src/cc/mallet/share/casutton/
#    creating: mallet-2.0.8/src/cc/mallet/share/casutton/ner/
#   inflating: mallet-2.0.8/src/cc/mallet/share/casutton/ner/ConllNer2003Sentence2TokenSequence.java
#    creating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/casutton/
#    creating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/casutton/ner/
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/casutton/ner/._ConllNer2003Sentence2TokenSequence.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/casutton/._ner
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/._casutton
#    creating: mallet-2.0.8/src/cc/mallet/share/mccallum/
#    creating: mallet-2.0.8/src/cc/mallet/share/mccallum/ner/
#   inflating: mallet-2.0.8/src/cc/mallet/share/mccallum/ner/TUI.java
#    creating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/mccallum/
#    creating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/mccallum/ner/
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/mccallum/ner/._TUI.java
#   inflating: mallet-2.0.8/src/cc/mallet/share/mccallum/ner/package.html
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/mccallum/ner/._package.html
#   inflating: mallet-2.0.8/src/cc/mallet/share/mccallum/ner/TokenSequenceDocHeader.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/mccallum/ner/._TokenSequenceDocHeader.java
#   inflating: mallet-2.0.8/src/cc/mallet/share/mccallum/ner/ConllNer2003Sentence2TokenSequence.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/mccallum/ner/._ConllNer2003Sentence2TokenSequence.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/mccallum/._ner
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/._mccallum
#    creating: mallet-2.0.8/src/cc/mallet/share/weili/
#    creating: mallet-2.0.8/src/cc/mallet/share/weili/ner/
#   inflating: mallet-2.0.8/src/cc/mallet/share/weili/ner/WordTransformation.java
#    creating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/weili/
#    creating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/weili/ner/
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/weili/ner/._WordTransformation.java
#    creating: mallet-2.0.8/src/cc/mallet/share/weili/ner/enron/
#   inflating: mallet-2.0.8/src/cc/mallet/share/weili/ner/enron/TUI.java
#    creating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/weili/ner/enron/
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/weili/ner/enron/._TUI.java
#   inflating: mallet-2.0.8/src/cc/mallet/share/weili/ner/enron/EnronMessage2TokenSequence.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/weili/ner/enron/._EnronMessage2TokenSequence.java
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/weili/ner/._enron
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/weili/._ner
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/share/._weili
#   inflating: __MACOSX/mallet-2.0.8/src/cc/mallet/._share
#   inflating: __MACOSX/mallet-2.0.8/src/cc/._mallet
#   inflating: __MACOSX/mallet-2.0.8/src/._cc
#   inflating: __MACOSX/mallet-2.0.8/._src
#   inflating: __MACOSX/._mallet-2.0.8

# %%
import os

# %%
df.head()
# Out:
#             User  ... sentiment
# 0  michaelbarata  ...  positive
# 1    fvnclothing  ...  negative
# 2       jourdaaa  ...  positive
# 3     BebitoToys  ...   neutral
# 4    leverage_cr  ...   neutral
#
# [5 rows x 14 columns]

# %%
os.environ['MALLET_HOME'] = '/content/mallet-2.0.8'
mallet_path = '/content/mallet-2.0.8/bin/mallet'

# %%
 #Topic modeling
# spacy for lemmatization
import spacy;
import en_core_web_sm
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Plotting tools
from pprint import pprint
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

# %%
# tokenize each sentence into a list of words, removing punctuations
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(df['text_nlp']))

# Remove Stop and common Words
stopwords = nltk.corpus.stopwords.words('english')
# 'home', 'stay','new','york', 'time',
newStopWords =  ['s','t',  'm', 're','don','ve','2', '3', '1', 
                 'it', 'i', 'us', 'get', 'you', 'let', 'going', 'know', 
                'make', 'take', 'still','got', 'can', 'this', 'all', 'me','go',
                'even', 'here', 'well', 'much', 'many', 'way', 'want', 'every', 'little']
stopwords.extend(newStopWords)

data_words = [[word for word in doc if word not in stopwords] for doc in data_words]

# %%
# restrict words to only noun, adjective, verb and adverb
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)
# Create Corpus
texts = data_lemmatized
# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# %% [markdown]
# ## Finding the optimal number of topics using LdaMallet model

# %%
start=24
limit=32
step=2
random = 155

# %%
# Write the function to compute coherence values for each model. 
# This could help us choose how many topics should be included into our model.

def compute_coherence_values(dictionary, corpus, texts, limit, start=1, step=1):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word,random_seed=random)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# compute coherence values for each model
#mallet_path = 'mallet-2.0.8/bin/mallet' # update this path
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lemmatized, start=start, limit=limit, step=step)

# %%
# plot the coherence values when number of topics equals to different numbers
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()
# The graph tell us about what number of topics to choose so we will choose 28 as it has maximum coherence score at that point

# %%
# plot the coherence values when number of topics equals to different numbers
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))

#If the coherence score seems to keep increasing, it may make better sense to pick the model that gave the highest CV before flattening out. This is exactly the case here.
#So for further steps I will choose the model with 28 topics itself.
# Out:
# Num Topics = 24  has Coherence Value of 0.3534
# Num Topics = 26  has Coherence Value of 0.3595
# Num Topics = 28  has Coherence Value of 0.368
# Num Topics = 30  has Coherence Value of 0.3772

# %% [markdown]
# ## Finding Key Words for each topic using optimal LdaMallet model

# %%
#mallet_path = 'mallet-2.0.8/bin/mallet' # update this path
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, 
                                             corpus=corpus,
                                             num_topics=26, 
                                             id2word=id2word,
                                             random_seed = 155)

# %%
# Show Topics
model_topics = ldamallet.show_topics(formatted=False)

pprint(sorted(ldamallet.print_topics(num_words=4)))
# Out:
# [(0, '0.055*"follow" + 0.041*"post" + 0.041*"free" + 0.035*"hour"'),
#  (1, '0.137*"make" + 0.095*"happy" + 0.056*"smile" + 0.045*"world"'),
#  (2, '0.056*"set" + 0.053*"back" + 0.033*"goal" + 0.032*"high"'),
#  (3, '0.265*"day" + 0.114*"great" + 0.108*"start" + 0.048*"beautiful"'),
#  (4, '0.048*"face" + 0.042*"wear" + 0.041*"real" + 0.038*"mask"'),
#  (6, '0.080*"check" + 0.071*"call" + 0.064*"watch" + 0.060*"show"'),
#  (8, '0.102*"today" + 0.078*"fitness" + 0.061*"training" + 0.044*"gym"'),
#  (9, '0.178*"people" + 0.076*"life" + 0.031*"save" + 0.021*"virus"'),
#  (10, '0.288*"time" + 0.071*"find" + 0.046*"long" + 0.046*"end"'),
#  (11, '0.044*"eat" + 0.030*"full" + 0.026*"food" + 0.020*"episode"'),
#  (13, '0.143*"feel" + 0.085*"give" + 0.053*"strong" + 0.041*"bad"'),
#  (14, '0.095*"year" + 0.044*"month" + 0.029*"die" + 0.029*"person"'),
#  (15, '0.249*"work" + 0.061*"hard" + 0.057*"mind" + 0.051*"put"'),
#  (16, '0.199*"love" + 0.102*"friend" + 0.068*"family" + 0.051*"listen"'),
#  (18, '0.068*"health" + 0.045*"care" + 0.044*"talk" + 0.043*"mental"'),
#  (19, '0.129*"week" + 0.101*"class" + 0.077*"live" + 0.055*"join"'),
#  (21, '0.074*"workout" + 0.044*"exercise" + 0.034*"minute" + 0.034*"side"'),
#  (22, '0.062*"order" + 0.048*"ready" + 0.047*"social" + 0.045*"walk"'),
#  (23, '0.045*"positive" + 0.037*"continue" + 0.033*"death" + 0.027*"case"'),
#  (25, '0.208*"good" + 0.110*"morning" + 0.081*"night" + 0.054*"learn"')]

# %%
topics = pd.DataFrame(sorted(ldamallet.print_topics(num_words=10)))
topics.columns = ['Topic_num','Key_words']
topics.to_csv('28_topics_2.csv',index = False)

# %%
topics.head()
#This csv tell us about the keywords about each topic
'''
here in 0.171*"people" 
0.0171 is percentage score
and "people" is keyboard 
'''
# Out:
# '\nhere in 0.171*"people" \n0.0171 is percentage score\nand "people" is keyboard \n'

# %%
# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
#More the coherence score more is better keywords
# Out:
# Coherence Score:  0.3595067689669032

# %% [markdown]
# ## Topic vector

# %% [markdown]
# ### Finding the dominant topic in each sentence
# One of the practical application of topic modeling is to determine what topic a given document is about.
#
# To find that, we find the topic number that has the highest percentage contribution in that document.
#
# The format_topics_sentences() function below nicely aggregates this information in a presentable table.

# %%
def format_topics_sentences(ldamodel=ldamallet, corpus=corpus, texts=df["text_nlp"]):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = sent_topics_df.join(contents)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamallet, corpus=corpus, texts=df["text_nlp"])
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show

# %%
df_dominant_topic.head(100)
# Out:
#     Document_No  ...                                               Text
# 0             0  ...                      new blog post true connection
# 1             0  ...                                   oh reunion heyyy
# 2             0  ...  couldn t accurate mls new home listing thanks ...
# 3             0  ...  goldenrulewill via lovewillam_ atrainlive make...
# 4             0  ...  hey maxwell meets premature end near future on...
# ..          ...  ...                                                ...
# 95            8  ...  kenzie believes got this full episode pn frien...
# 96            8  ...  open studios continue w cs_studios_nyc 7 30pm ...
# 97            8  ...               today sometimes work today one times
# 98            8  ...                        warriors this includes you
# 99            9  ...  don t care south don t care reverse care safet...
#
# [100 rows x 5 columns]

# %%
df.to_csv('df_dominant_topic.csv') 
files.download('df_dominant_topic.csv')

# %% [markdown]
# ### Find the most representative document for each topic
# Sometimes just the topic keywords may not be enough to make sense of what a topic is about. So, to help with understanding the topic, you can find the documents a given topic has contributed to the most and infer the topic by reading that document. Whew!!

# %%
# Group top 5 sentences under each topic
sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# Show
sent_topics_sorteddf_mallet.head()
# Out:
#    Topic_Num  ...                                               Text
# 0        0.0  ...   it s been tooo lonngg since we took the time ...
# 1        1.0  ...             wrigleychicky1 y all grounded weekend
# 2        2.0  ...                                                NaN
# 3        3.0  ...          gym packeedd let s get planet fitness fam
# 4        4.0  ...                                                NaN
#
# [5 rows x 4 columns]

# %%
sent_topics_sorteddf_mallet
# Out:
#     Topic_Num  ...                                               Text
# 0         0.0  ...   it s been tooo lonngg since we took the time ...
# 1         1.0  ...             wrigleychicky1 y all grounded weekend
# 2         2.0  ...                                                NaN
# 3         3.0  ...          gym packeedd let s get planet fitness fam
# 4         4.0  ...                                                NaN
# 5         5.0  ...                                  new york new york
# 6         6.0  ...                         fat pad roselle new jersey
# 7         7.0  ...  making cardio ad workouts fun i m about celebr...
# 8         8.0  ...                                                NaN
# 9         9.0  ...           sally evil tag someone hates love sally
# 10       10.0  ...                                                NaN
# 11       11.0  ...                                                NaN
# 12       12.0  ...                                 have are figuring
# 13       13.0  ...  nike air jordan 1 follow romaboss orden whatsapp
# 14       14.0  ...                                                NaN
# 15       15.0  ...  taco tuesday here celebrate delicious shrimp t...
# 16       16.0  ...  yoga treat depression research shows specific ...
# 17       17.0  ...              it s covid party cardiac icu tonight
# 18       18.0  ...                                       making kick
# 19       19.0  ...                                                NaN
# 20       20.0  ...                              holds true especially
# 21       21.0  ...                        he s los angeles california
# 22       22.0  ...                                         reflection
# 23       23.0  ...                     spent lot time texting laptop
# 24       24.0  ...                                     tell purchase
# 25       25.0  ...  mom better mom sent favorite cookies tiffstrea...
#
# [26 rows x 4 columns]

# %%
df.to_csv('sent_topics_sorteddf_mallet.csv') 
files.download('sent_topics_sorteddf_mallet.csv')

# %% [markdown]
# The tabular output above actually has 25 rows, one each for a topic. It has the topic number, the keywords, and the most representative document. The Perc_Contribution column is nothing but the percentage contribution of the topic in the given document.

# %% [markdown]
# ### Topic distribution across documents
# Finally, we want to understand the volume and distribution of topics in order to judge how widely it was discussed. The below table exposes that information.

# %%
# Number of Documents for Each Topic
topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()

#Percentage of Documents for Each Topic
topic_contribution = round(topic_counts/topic_counts.sum(), 4)

# Topic Number and Keywords
topic_num_keywords = df_topic_sents_keywords[['Dominant_Topic', 'Topic_Keywords']]

# Concatenate Column wise
df_dominant_topics = pd.concat([topic_num_keywords, topic_counts, topic_contribution], axis=1)

# Change Column names
df_dominant_topics.columns = ['Dominant_Topic', 'Topic_Keywords', 'Num_Documents', 'Perc_Documents']
df_dominant_topics=df_dominant_topics.drop_duplicates()
# Show
print(df_dominant_topics)
# Out:
#        Dominant_Topic  ... Perc_Documents
# 0.0               0.0  ...         0.1703
# 1.0               9.0  ...         0.0399
# 2.0              15.0  ...         0.0356
# 3.0              15.0  ...         0.0350
# 4.0              17.0  ...         0.0433
# 5.0              13.0  ...         0.0314
# 6.0               7.0  ...         0.0361
# 7.0              14.0  ...         0.0352
# 8.0               2.0  ...         0.0322
# 9.0              23.0  ...         0.0362
# 10.0             10.0  ...         0.0381
# 11.0             14.0  ...         0.0352
# 12.0              0.0  ...         0.0355
# 13.0              5.0  ...         0.0319
# 14.0              2.0  ...         0.0298
# 15.0              6.0  ...         0.0379
# 16.0              4.0  ...         0.0374
# 17.0              1.0  ...         0.0253
# 18.0             16.0  ...         0.0325
# 19.0              0.0  ...         0.0282
# 20.0              0.0  ...         0.0330
# 21.0             21.0  ...         0.0264
# 22.0             24.0  ...         0.0261
# 24.0              9.0  ...         0.0298
# 25.0             11.0  ...         0.0295
# 26.0             14.0  ...            NaN
# 27.0              7.0  ...            NaN
# 28.0              8.0  ...            NaN
# 29.0             12.0  ...            NaN
# 30.0             19.0  ...            NaN
# 31.0             10.0  ...            NaN
# 33.0             24.0  ...            NaN
# 34.0              1.0  ...            NaN
# 36.0              4.0  ...            NaN
# 37.0             21.0  ...            NaN
# 38.0              0.0  ...            NaN
# 39.0             22.0  ...            NaN
# 42.0              6.0  ...            NaN
# 43.0             11.0  ...            NaN
# 46.0             15.0  ...            NaN
# 47.0             23.0  ...            NaN
# 50.0              3.0  ...            NaN
# 52.0              9.0  ...            NaN
# 58.0             16.0  ...            NaN
# 60.0              2.0  ...            NaN
# 71.0             13.0  ...            NaN
# 76.0              5.0  ...            NaN
# 89.0             20.0  ...            NaN
# 95.0             25.0  ...            NaN
# 107.0            17.0  ...            NaN
# 110.0            18.0  ...            NaN
#
# [51 rows x 4 columns]

# %%
df.to_csv('df_dominant_topics.csv') 
files.download('df_dominant_topics.csv')

# %% [markdown]
# ## Topic modelling analysis

# %%
print(df_dominant_topic.shape)
print(df.shape)
# Out:
# (35159, 5)
# (28022, 14)

# %%
topic_names=sent_topics_sorteddf_mallet["Keywords"]

# %%
topic_names=list(topic_names)

# %%
print(topic_names)
# Out:
# ['follow, post, free, hour, online, sign, personal, deal, session, store', 'make, happy, smile, world, heart, favorite, enjoy, top, birthday, bring', 'set, back, goal, high, rest, double, power, tip, strength, push', 'day, great, start, beautiful, move, open, forward, studio, miss, reminder', 'face, wear, real, mask, leave, lot, man, create, woman, head', 'today, tonight, wait, live, pm, book, link, bio, music, tune', 'check, call, watch, show, video, message, youtube, full, guy, schedule', 'thing, day, change, meditation, place, step, grateful, wake, inspire, plan', 'today, fitness, training, gym, back, train, kid, job, win, client', 'people, life, save, virus, matter, line, kill, risk, doctor, sick', 'time, find, long, end, challenge, energy, perfect, spend, soul, choose', 'eat, full, food, episode, dance, dinner, water, meal, randsomnote, fresh', 'life, stop, big, play, lose, story, happen, hear, experience, dream', 'feel, give, strong, bad, good, light, hit, remember, back, art', 'year, month, die, person, bring, ago, peace, pretty, baby, tough', 'work, hard, mind, put, fear, body, focus, read, finally, miss', 'love, friend, family, listen, share, send, enjoy, photo, awareness, repost', 'support, essential, worker, moment, close, business, community, action, open, school', 'health, care, talk, mental, important, depression, struggle, anxiety, stress, issue', 'week, class, live, join, tomorrow, daily, virtual, yoga, free, member', 'stay, home, safe, healthy, hope, hand, fit, foot, active, wash', 'workout, exercise, minute, side, body, leg, weight, burn, low, add', 'order, ready, social, walk, practice, distancing, delivery, distance, park, pick', 'positive, continue, death, case, fight, eye, state, test, patient, black', 'run, today, weekend, part, easy, mile, late, room, fast, stretch', 'good, morning, night, learn, amazing, fun, early, turn, grow, bless']

# %% [markdown]
# ### Combining the topic names with or original dataset

# %%
topics_docs = []
for m in ldamallet[corpus]:
    topics_docs.append(m)

train_vecs = []
for i in topics_docs:
    topic_vec = [j[1] for j in i]
    train_vecs.append(topic_vec) 

topic_dis = pd.DataFrame(train_vecs,columns=topic_names)
topic_dis.head()

df= df.join(topic_dis)
df.head(2)
# Out:
#               User  ... good, morning, night, learn, amazing, fun, early, turn, grow, bless
# 0    michaelbarata  ...                                           0.035613
# 0  _TraceDollFace_  ...                                           0.035613
#
# [2 rows x 40 columns]

# %%
df.shape
# Out:
# (28022, 40)

# %%
df.to_csv('df.csv') 
files.download('df.csv')

# %% [markdown]
# ### Finding polarity of all 25 topics

# %%
topic_list = df.columns[14:39]
topic_mean = df.iloc[:,14:39].mean().values

for i in range(len(topic_list)):
    df[i] = np.where(df[topic_list[i]] > 0.08,1,0)
    
topic_polarity = list()
for i in range(25):
    topic_polarity.append(df[df[i]==1]['polarity'].mean())
    
topic_polarity = pd.DataFrame({'Topics':topic_list,'Polarity':topic_polarity})
topic_polarity=topic_polarity.sort_values(by = ['Polarity'],ascending=False)
topic_polarity.head()
# Out:
#                                                Topics  Polarity
# 4   face, wear, real, mask, leave, lot, man, creat...  0.177381
# 22  order, ready, social, walk, practice, distanci...  0.176612
# 20  stay, home, safe, healthy, hope, hand, fit, fo...  0.171516
# 14  year, month, die, person, bring, ago, peace, p...  0.165378
# 8   today, fitness, training, gym, back, train, ki...  0.161518

# %%
from google.colab import files
df.to_csv('topic_polarity.csv') 
files.download('topic_polarity.csv')

# %% [markdown]
# Notebook created by **Archit Bansal**
# *contact me:*
#  * [Github](https://github.com/j-a-r-v-i )
#  * [linkedin](www.linkedin.com/in/archit-bansal-3248b0162)
#
#  Really grateful to **Aradhana** who helped me to complete my work
